# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# 샘플에 활용할 데이터셋 제작
def make_linear(w = 0.5, b = 0.8, size = 50, noise = 1.0):
  x = np.random.rand(size)
  y = w * x + b
  noise = np.random.uniform(-abs(noise), abs(noise), size = y.shape)
  yy = y + noise
  plt.figure(figsize = (10, 7))
  plt.plot(x, y, color = 'r', label = f'y = {w} * x + {b}')
  plt.scatter(x, yy, label='data')
  plt.legend(fontsize = 20)
  plt.show()
  print(f'w: {w}, b: {b}')
  return x, yy

x, y = make_linear(w = 0.3, b = 0.5, size = 100, noise = 0.01)
# Out:
# w: 0.3, b: 0.5

# %%
# 반복횟수 = epoch
num_epoch = 1000

#학습률(learning_rate)
learning_rate = 0.005

#에러 기록
errors = []

#랜덤 값으로 w, b 초기화
w = np.random.uniform(low = 0.0, high = 1.0)
b = np.random.uniform(low = 0.0, high = 1.0)

for epoch in range(num_epoch):
  #가설값 설정
  y_hat = w * x + b

  #loss function def
  error = 0.5*((y_hat - y) * x).sum()
  if error < 0.005:
    break
  
  #gradient 미분 계산
  w = w - learning_rate * ((y_hat - y) * x).sum()
  b = b - learning_rate * (y_hat - y).sum()

  errors.append(error)

  if epoch % 5 ==0:
    print("{0:2} w = {1:.5f}, b = {2:.5f} error = {3:.5f}".format(epoch, w, b, error))


print("-------" * 15)

print("{0:2} w = {1:.1f}, b = {2:.1f} error = {3:.5f}".format(epoch, w, b, error))
# Out:
#  0 w = 0.89683, b = 0.17511 error = 3.68683
#  5 w = 0.79387, b = 0.21519 error = 1.76991
# 10 w = 0.71443, b = 0.26088 error = 1.47879
# 15 w = 0.64779, b = 0.29929 error = 1.24096
# 20 w = 0.59187, b = 0.33152 error = 1.04140
# 25 w = 0.54494, b = 0.35856 error = 0.87393
# 30 w = 0.50556, b = 0.38126 error = 0.73340
# 35 w = 0.47251, b = 0.40031 error = 0.61546
# 40 w = 0.44477, b = 0.41629 error = 0.51649
# 45 w = 0.42150, b = 0.42971 error = 0.43343
# 50 w = 0.40197, b = 0.44097 error = 0.36373
# 55 w = 0.38558, b = 0.45041 error = 0.30524
# 60 w = 0.37182, b = 0.45834 error = 0.25616
# 65 w = 0.36028, b = 0.46499 error = 0.21496
# 70 w = 0.35059, b = 0.47058 error = 0.18040
# 75 w = 0.34246, b = 0.47526 error = 0.15139
# 80 w = 0.33564, b = 0.47919 error = 0.12704
# 85 w = 0.32991, b = 0.48249 error = 0.10661
# 90 w = 0.32511, b = 0.48526 error = 0.08947
# 95 w = 0.32108, b = 0.48759 error = 0.07508
# 100 w = 0.31770, b = 0.48954 error = 0.06301
# 105 w = 0.31486, b = 0.49117 error = 0.05288
# 110 w = 0.31247, b = 0.49255 error = 0.04437
# 115 w = 0.31047, b = 0.49370 error = 0.03724
# 120 w = 0.30880, b = 0.49466 error = 0.03125
# 125 w = 0.30739, b = 0.49548 error = 0.02622
# 130 w = 0.30621, b = 0.49616 error = 0.02201
# 135 w = 0.30521, b = 0.49673 error = 0.01847
# 140 w = 0.30438, b = 0.49721 error = 0.01550
# 145 w = 0.30368, b = 0.49761 error = 0.01301
# 150 w = 0.30310, b = 0.49795 error = 0.01091
# 155 w = 0.30261, b = 0.49823 error = 0.00916
# 160 w = 0.30219, b = 0.49847 error = 0.00769
# 165 w = 0.30185, b = 0.49867 error = 0.00645
# 170 w = 0.30156, b = 0.49884 error = 0.00541
# ---------------------------------------------------------------------------------------------------------
# 173 w = 0.3, b = 0.5 error = 0.00487

# %%
plt.figure(figsize = (10, 7))
plt.plot(errors)
plt.xlabel('Epochs')
plt.ylabel('Error')
plt.show
# Out:
# <function matplotlib.pyplot.show>
